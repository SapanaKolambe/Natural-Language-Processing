# %% [markdown]
# <a href="https://colab.research.google.com/github/SapanaKolambe/Natural-Language-Processing/blob/main/2_part_of_speech_tagging_and_chunking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Parts Of Speech Tags
#
#
# Parts of speech tags are the properties of the words, which define their main context, functions, and usage in a sentence. Some of the commonly used parts of speech tags are,
#
# Nouns: Which defines any object or entity
#
# Verbs: That defines some action.
#
# Adjectives and Adverbs: This acts as a modifier, quantifier, or intensifier in any sentence.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Use cases of POS Tags
# Parts of speech tags have a large number of applications and they are used in a variety of tasks such as
#
# *   Text Cleaning
# *   Feature Engineering tasks
# *   Word sense disambiguation
#
# For example, consider these sentences
#
#
# ![image.png](data:image/png;base64,...)
#
# In both sentences, the keyword book is used, but in sentence one, it is used as a verb. While in sentence two it is used as a noun.

# %% [markdown]
# Importing the libraries
#
# Downloading the packages.

# %%
import nltk
from nltk import word_tokenize
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('tagsets')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets.zip.
# True

# %% [markdown]
# Viewing the POST tagsets.

# %%
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
# ...

# %%
sentence = word_tokenize("Let’s check for the tags for any sentence.")
nltk.pos_tag(sentence)
# Out:
# [('Let', 'VB'),
#  ('’', 'NNP'),
#  ('s', 'VB'),
#  ('check', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('tags', 'NNS'),
#  ('for', 'IN'),
#  ('any', 'DT'),
#  ('sentence', 'NN'),
#  ('.', '.')]

# %% [markdown]
# Examples on on homonyms.

# %%
sentence = word_tokenize("applicant is removed from applicant list of the job ")
nltk.pos_tag(sentence)
# Out:
# [('applicant', 'NN'),
#  ('is', 'VBZ'),
#  ('removed', 'VBN'),
#  ('from', 'IN'),
#  ('applicant', 'JJ'),
#  ('list', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('job', 'NN')]

# %%
sentence = word_tokenize("allow us to add lines in list of allow actions")
nltk.pos_tag(sentence)
# Out:
# [('allow', 'VB'),
#  ('us', 'PRP'),
#  ('to', 'TO'),
#  ('add', 'VB'),
#  ('lines', 'NNS'),
#  ('in', 'IN'),
#  ('list', 'NN'),
#  ('of', 'IN'),
#  ('allow', 'JJ'),
#  ('actions', 'NNS')]

# %% [markdown]
# import the brown corpus for some more features

# %%
nltk.download('brown')
from nltk.corpus import brown
brown.categories()
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
text_news = nltk.Text(word.lower() for word in nltk.corpus.brown.words(categories='news'))
text_news
# Out:
# <Text: the fulton county grand jury said friday an...>

# %%
brown_news_tagged = brown.tagged_words(categories='news', tagset='universal')
nltk.download('universal_tagset')
tag_fd = nltk.FreqDist(tag for (word, tag) in brown_news_tagged)
tag_fd.most_common()
# Out:
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [('NOUN', 30654),
#  ('VERB', 14399),
#  ('ADP', 12355),
#  ('.', 11928),
#  ('DET', 11389),
#  ('ADJ', 6706),
#  ('ADV', 3349),
#  ('CONJ', 2717),
#  ('PRON', 2535),
#  ('PRT', 2264),
#  ('NUM', 2166),
#  ('X', 92)]

# %%
tag_fd.plot(cumulative=True)

# %%
text_news.similar('man')
# Out:
# meeting ball state house day president team score plan session schools
# people person way period salary company corporation game congo

# %%
text_news.similar('said')
# Out:
# of in is for expected made that and at added says reported used
# thought on asked told given able began

# %%
text_news.similar('the')
# Out:
# a his this their its that any an all and some each these one our four
# which it washington dallas

# %%
nltk.download('indian')
nltk.corpus.indian.tagged_words('hindi.pos')
# Out:
# [nltk_data] Downloading package indian to /root/nltk_data...
# [nltk_data]   Unzipping corpora/indian.zip.
# [('पूर्ण', 'JJ'), ('प्रतिबंध', 'NN'), ('हटाओ', 'VFM'), ...]

# %%
text_hobbies = nltk.Text(word.lower() for word in nltk.corpus.brown.words(categories='hobbies'))
text_hobbies
# Out:
# <Text: too often a beginning bodybuilder has to do...>

# %%
brown_hobbies_tagged = brown.tagged_words(categories='hobbies', tagset='universal')
nltk.download('universal_tagset')
tag_fd1 = nltk.FreqDist(tag for (word, tag) in brown_hobbies_tagged)
tag_fd1.most_common()
# Out:
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# [('NOUN', 21276),
#  ('VERB', 12733),
#  ('ADP', 10070),
#  ('.', 9792),
#  ('DET', 9497),
#  ('ADJ', 6559),
#  ('ADV', 3736),
#  ('CONJ', 2948),
#  ('PRON', 2334),
#  ('PRT', 1889),
#  ('NUM', 1426),
#  ('X', 85)]

# %%
# Source: https://textblob.readthedocs.io/en/dev/quickstart.html#part-of-speech-tagging
from textblob import TextBlob
wiki = TextBlob("Python is a high-level, general-purpose programming language.")
wiki.tags
# Out:
# [('Python', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('high-level', 'JJ'),
#  ('general-purpose', 'JJ'),
#  ('programming', 'NN'),
#  ('language', 'NN')]

# %%
from nltk.tag import DefaultTagger
default_tagger = DefaultTagger('NN')
list(default_tagger.tag('This is a test'.split()))
# Out:
# [('This', 'NN'), ('is', 'NN'), ('a', 'NN'), ('test', 'NN')]

# %%
import spacy
 
nlp = spacy.load('en_core_web_sm')
doc = nlp(u'Apple is looking at buying U.K. startup for $1 billion')
 
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# Apple Apple PROPN NNP nsubj Xxxxx True False
# is be AUX VBZ aux xx True True
# looking look VERB VBG ROOT xxxx True False
# at at ADP IN prep xx True True
# buying buy VERB VBG pcomp xxxx True False
# U.K. U.K. PROPN NNP dobj X.X. False False
# startup startup NOUN NN dobj xxxx True False
# for for ADP IN prep xxx True True
# $ $ SYM $ quantmod $ False False
# 1 1 NUM CD compound d False False
# billion billion NUM CD pobj xxxx True False

# %% [markdown]
# **Chunking** in NLP is a process to take small pieces of information and group them into large units.
#
# The primary use of Chunking is making groups of “noun phrases.” It is used to add structure to the sentence by following POS tagging combined with regular expressions. The resulted group of words are called “chunks.” It is also called shallow parsing.
#
# In shallow parsing, there is maximum one level between roots and leaves while deep parsing comprises of more than one level. Shallow parsing is also called light parsing or chunking.
#
# **Rules for Chunking:**
#
# There are no pre-defined rules, but you can combine them according to need and requirement.
#
# For example, you need to tag Noun, verb (past tense), adjective, and coordinating junction from the sentence.
#
# You can use the rule as below chunk:
#
# {<NN.?>*<VBD.?>*<JJ.?>*<CC>?}
#
# Following symbol shows what they means:
#
# ( .	):  Any character except new line
#
#
# ( * ): Match 0 or more repetitions
#
# ( ? ): Match 0 or 1 repetitions

# %%
from nltk import pos_tag
from nltk import RegexpParser
text ="learn php from guru99 and make study easy".split()
print("After Split:",text)
# Out:
# After Split: ['learn', 'php', 'from', 'guru99', 'and', 'make', 'study', 'easy']

# %%
tokens_tag = pos_tag(text)
print("After Token:",tokens_tag)
# Out:
# After Token: [('learn', 'JJ'), ('php', 'NN'), ('from', 'IN'), ('guru99', 'NN'), ('and', 'CC'), ('make', 'VB'), ('study', 'NN'), ('easy', 'JJ')]

# %%
patterns= """mychunk:{<NN.?>*<VBD.?>*<JJ.?>*<CC>?}"""
chunker = RegexpParser(patterns)
print("After Regex:",chunker)
# Out:
# After Regex: chunk.RegexpParser with 1 stages:
# RegexpChunkParser with 1 rules:
#        <ChunkRule: '<NN.?>*<VBD.?>*<JJ.?>*<CC>?'>

# %%
output = chunker.parse(tokens_tag)
print("After Chunking",output)
# Out:
# After Chunking (S
#   (mychunk learn/JJ)
#   (mychunk php/NN)
#   from/IN
#   (mychunk guru99/NN and/CC)
#   make/VB
#   (mychunk study/NN easy/JJ))

# %%
from collections import Counter
counts = Counter( tag for word,  tag in tokens_tag)
print(counts)
# Out:
# Counter({'NN': 3, 'JJ': 2, 'IN': 1, 'CC': 1, 'VB': 1})
